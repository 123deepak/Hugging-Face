# %%
from huggingface_hub import HfApi

# Initialize the API
api = HfApi()

# List models with a limit of 5, sorted by downloads
models = api.list_models(
    filter="image-classification",
    limit=5,
    sort="downloads",
    full=True  # Include all model card metadata
)

# Print the model name, downloads, and size
print("Top 5 Models by Downloads and Their Sizes:\n")
for model in models:
    # Access downloads and model size in bytes
    downloads = model.downloads

    print(f"Model: {model.modelId}, Downloads: {downloads}")
# Out:
# Top 5 Models by Downloads and Their Sizes:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Model: microsoft/resnet-50, Downloads: 155324332
# Model: timm/resnet50.a1_in1k, Downloads: 21186107
# Model: timm/mobilenetv3_small_100.lamb_in1k, Downloads: 20430721
# Model: google/vit-base-patch16-224, Downloads: 5500378
# Model: WinKawaks/vit-tiny-patch16-224, Downloads: 5102482

# %%
from transformers import pipeline
task = pipeline(task='image-classification', model='google/vit-base-patch16-224')
# Out:
# Fast image processor class <class 'transformers.models.vit.image_processing_vit_fast.ViTImageProcessorFast'> is available for this model. Using slow image processor class. To use the fast image processor class set `use_fast=True`.
# Device set to use cpu

# %%
from PIL import Image
# Photo by Ryan Klaus from Pexels: https://www.pexels.com/photo/the-church-of-saint-peter-at-the-porto-venere-in-italy-11898887/
Image.open('/content/pexels-photo-11898887.jpeg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x750>

# %%
task(Image.open('/content/pexels-photo-11898887.jpeg'))
# Out:
# [{'label': 'promontory, headland, head, foreland',
#   'score': 0.7694703936576843},
#  {'label': 'seashore, coast, seacoast, sea-coast',
#   'score': 0.19030113518238068},
#  {'label': 'cliff, drop, drop-off', 'score': 0.013870359398424625},
#  {'label': 'beacon, lighthouse, beacon light, pharos',
#   'score': 0.008466648869216442},
#  {'label': 'lakeside, lakeshore', 'score': 0.004146538209170103}]
